# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Mon Jun  7 13:46:10 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/NahumFGz/svoice.git
# Out:
# Cloning into 'svoice'...
# remote: Enumerating objects: 407, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 407 (delta 11), reused 11 (delta 11), pack-reused 386
# Receiving objects: 100% (407/407), 5.19 MiB | 18.46 MiB/s, done.
# Resolving deltas: 100% (178/178), done.

# %%
cd svoice
# Out:
# /content/svoice

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 81kB 2.3MB/s
# ...
#      |████████████████████████████████| 14.5MB 489kB/s
# ...
#      |████████████████████████████████| 71kB 8.5MB/s
# ...
#      |████████████████████████████████| 122kB 52.1MB/s
# ...
#      |████████████████████████████████| 6.8MB 26.4MB/s
# ...
#      |████████████████████████████████| 1.6MB 50.0MB/s
# ...
#      |████████████████████████████████| 3.6MB 41.2MB/s
# ...
#      |████████████████████████████████| 112kB 50.2MB/s
# ...
#      |████████████████████████████████| 748.8MB 22kB/s
# ...
#      |████████████████████████████████| 20.2MB 1.5MB/s
# ...
#      |████████████████████████████████| 645kB 45.1MB/s
# ...
#   Created wheel for pesq: filename=pesq-0.0.1-cp37-cp37m-linux_x86_64.whl size=160872 sha256=683f8466197754f23eb0b53cfab28649362860b75e44dc2596e791a0bf199d29
#   Stored in directory: /root/.cache/pip/wheels/42/a8/44/839b6f59a7d142d84ff06bfabaaad2a3e60408ee153de9bf13
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/svoice/train.py epochs=355
# Out:
# [2021-06-07 13:51:45,984][__main__][INFO] - For logs, checkpoints and samples check /content/drive/My Drive/ResultadosEntrenamiento/Audio_Separation/dn_svoice/outputs/exp_epochs=355
# [2021-06-07 13:51:47,885][__main__][INFO] - Running on host 144a0118f638
# [2021-06-07 13:51:51,120][svoice.solver][INFO] - Loading checkpoint model: checkpoint.th
# [2021-06-07 13:52:03,719][svoice.solver][INFO] - Replaying metrics from previous run
# [2021-06-07 13:52:03,719][svoice.solver][INFO] - Epoch 0: train=-0.41330 valid=-1.32448 best=-1.32448
# [2021-06-07 13:52:03,720][svoice.solver][INFO] - Epoch 1: train=-1.10057 valid=-2.57214 best=-2.57214 sisnr=2.37631 pesq=0.00000 stoi=0.00000
# [2021-06-07 13:52:03,720][svoice.solver][INFO] - Epoch 2: train=-1.62423 valid=-3.65139 best=-3.65139
# [2021-06-07 13:52:03,720][svoice.solver][INFO] - Epoch 3: train=-2.10893 valid=-4.11549 best=-4.11549 sisnr=3.86015 pesq=0.00000 stoi=0.00000
# ...

# %%
#!python -m svoice.data.audio '/content/drive/MyDrive/DataSets/AudioSets/dataset_8000_fr_n_5/mix' > mix.json

# %%
#!python -m svoice.data.audio '/content/drive/MyDrive/DataSets/AudioSets/dataset_8000_fr_n_5/s1' > s1.json

# %%
#!python -m svoice.data.audio '/content/drive/MyDrive/DataSets/AudioSets/dataset_8000_fr_n_5/s2' > s2.json

# %% [markdown]
# # Evaluating

# %%
#!python -m svoice.evaluate /content/drive/MyDrive/ResultadosEntrenamiento/Audio_Separation/dn_svoice/outputs/exp_/checkpoint.th /content/svoice/egs/debug/tr

# %%
print("Fin!!!")
