# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Tue Jun  8 14:13:41 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    25W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/NahumFGz/svoice.git
# Out:
# Cloning into 'svoice'...
# remote: Enumerating objects: 407, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 407 (delta 11), reused 11 (delta 11), pack-reused 386
# Receiving objects: 100% (407/407), 5.19 MiB | 6.04 MiB/s, done.
# Resolving deltas: 100% (178/178), done.

# %%
cd svoice
# Out:
# /content/svoice

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 81kB 2.1MB/s
# ...
#      |████████████████████████████████| 14.5MB 475kB/s
# ...
#      |████████████████████████████████| 71kB 10.8MB/s
# ...
#      |████████████████████████████████| 122kB 49.5MB/s
# ...
#      |████████████████████████████████| 6.8MB 34.4MB/s
# ...
#      |████████████████████████████████| 1.6MB 45.5MB/s
# ...
#      |████████████████████████████████| 3.6MB 40.4MB/s
# ...
#      |████████████████████████████████| 112kB 54.4MB/s
# ...
#      |████████████████████████████████| 81kB 12.0MB/s
# ...
#      |████████████████████████████████| 748.8MB 23kB/s
# ...
#      |████████████████████████████████| 20.2MB 1.3MB/s
# ...
#      |████████████████████████████████| 645kB 32.9MB/s
# ...
#   Created wheel for pesq: filename=pesq-0.0.1-cp37-cp37m-linux_x86_64.whl size=160870 sha256=79e9308bb0b3c2c57bd88115b808dc9498931d67303d0da2ccdb69a0da59109b
#   Stored in directory: /root/.cache/pip/wheels/42/a8/44/839b6f59a7d142d84ff06bfabaaad2a3e60408ee153de9bf13
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/svoice/train.py epochs=354 lr=5e-4
# Out:
# /usr/local/lib/python3.7/dist-packages/hydra/core/utils.py:143: UserWarning: register_resolver() is deprecated.
# See https://github.com/omry/omegaconf/issues/426 for migration instructions.
#
#   OmegaConf.register_resolver(name, f)
# [2021-06-08 14:20:50,818][__main__][INFO] - For logs, checkpoints and samples check /content/drive/My Drive/ResultadosEntrenamiento/Audio_Separation/dn_svoice/outputs/exp_epochs=354,lr=5e-4
# [2021-06-08 14:20:52,750][__main__][INFO] - Running on host 68bea3340528
# [2021-06-08 14:20:55,887][svoice.solver][INFO] - Loading checkpoint model: checkpoint.th
# [2021-06-08 14:21:17,387][svoice.solver][INFO] - Replaying metrics from previous run
# [2021-06-08 14:21:17,387][svoice.solver][INFO] - Epoch 0: train=-0.46712 valid=-1.47670 best=-1.47670
# [2021-06-08 14:21:17,388][svoice.solver][INFO] - Epoch 1: train=-1.08867 valid=-2.45088 best=-2.45088 sisnr=2.06901 pesq=0.00000 stoi=0.00000
# ...

# %%
#!python -m svoice.data.audio '/content/drive/MyDrive/DataSets/AudioSets/dataset_8000_fr_n_2/mix' > mix.json

# %%
#!python -m svoice.data.audio '/content/drive/MyDrive/DataSets/AudioSets/dataset_8000_fr_n_2/s1' > s1.json

# %%
#!python -m svoice.data.audio '/content/drive/MyDrive/DataSets/AudioSets/dataset_8000_fr_n_2/s2' > s2.json

# %% [markdown]
# # Evaluating

# %%
#!python -m svoice.evaluate /content/drive/MyDrive/ResultadosEntrenamiento/Audio_Separation/dn_svoice/outputs/exp_/checkpoint.th /content/svoice/egs/debug/tr

# %%
print("Fin!!!")
