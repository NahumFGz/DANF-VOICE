# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sun May 16 03:06:58 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/NahumFGz/svoice.git
# Out:
# Cloning into 'svoice'...
# remote: Enumerating objects: 250, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 250 (delta 70), reused 124 (delta 41), pack-reused 90
# Receiving objects: 100% (250/250), 5.16 MiB | 13.84 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
cd svoice
# Out:
# /content/svoice

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 81kB 3.8MB/s
# ...
#      |████████████████████████████████| 14.5MB 331kB/s
# ...
#      |████████████████████████████████| 71kB 8.8MB/s
# ...
#      |████████████████████████████████| 122kB 27.0MB/s
# ...
#      |████████████████████████████████| 6.8MB 30.1MB/s
# ...
#      |████████████████████████████████| 1.6MB 35.2MB/s
# ...
#      |████████████████████████████████| 3.6MB 36.6MB/s
# ...
#      |████████████████████████████████| 112kB 24.7MB/s
# ...
#      |████████████████████████████████| 748.8MB 25kB/s
# ...
#      |████████████████████████████████| 20.2MB 8.9MB/s
# ...
#      |████████████████████████████████| 645kB 19.4MB/s
# ...
#   Created wheel for pesq: filename=pesq-0.0.1-cp37-cp37m-linux_x86_64.whl size=160861 sha256=a0c337fadb852d5bf6a63bd2b00cdb7e7ad377c4c557d2a07a145e9d75fb5b31
#   Stored in directory: /root/.cache/pip/wheels/42/a8/44/839b6f59a7d142d84ff06bfabaaad2a3e60408ee153de9bf13
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/svoice/train.py
# Out:
# [2021-05-16 03:09:33,888][__main__][INFO] - For logs, checkpoints and samples check /content/drive/My Drive/ResultadosEntrenamiento/Audio_Separation/dn_svoice/outputs/exp_
# [2021-05-16 03:09:35,658][__main__][INFO] - Running on host 485df11fc035
# [2021-05-16 03:09:37,920][svoice.solver][INFO] - ----------------------------------------------------------------------
# [2021-05-16 03:09:37,920][svoice.solver][INFO] - Training...
# [W TensorIterator.cpp:918] Warning: Mixed memory format inputs detected while calling the operator. The operator will output contiguous tensor even if some of the inputs are in channels_last format. (function operator())
# [2021-05-16 03:37:55,163][svoice.solver][INFO] - Train | Epoch 1 | 1327/6638 | 0.8 it/sec | Loss 2.41550
# [2021-05-16 04:03:35,056][svoice.solver][INFO] - Train | Epoch 1 | 2654/6638 | 0.8 it/sec | Loss 2.21049
# [2021-05-16 04:29:13,835][svoice.solver][INFO] - Train | Epoch 1 | 3981/6638 | 0.8 it/sec | Loss 2.09806
# ...

# %%
#!python -m svoice.data.audio '/content/drive/MyDrive/DataSets/AudioSets/dataset_dn_30_seg/mix' > mix.json

# %%
#!python -m svoice.data.audio '/content/drive/MyDrive/DataSets/AudioSets/dataset_dn_30_seg/s1' > s1.json

# %%
#!python -m svoice.data.audio '/content/drive/MyDrive/DataSets/AudioSets/dataset_dn_30_seg/s2' > s2.json

# %% [markdown]
# # Evaluating

# %%
# !python -m svoice.evaluate /content/drive/MyDrive/ResultadosEntrenamiento/Audio_Separation/dn_svoice/outputs/exp_/checkpoint.th /content/svoice/egs/debug/tr

# %%
print("Fin!!!")
