# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Select the Runtime > "Change runtime type" menu to enable a GPU accelerator,
# and then re-execute this cell.

# %%
# !git clone https://github.com/NahumFGz/svoice.git
# Out:
# Cloning into 'svoice'...
# remote: Enumerating objects: 407, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 407 (delta 44), reused 73 (delta 39), pack-reused 328
# Receiving objects: 100% (407/407), 5.19 MiB | 17.91 MiB/s, done.
# Resolving deltas: 100% (173/173), done.

# %%
cd svoice
# Out:
# /content/svoice

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 81kB 2.1MB/s
# ...
#      |████████████████████████████████| 14.5MB 249kB/s
# ...
#      |████████████████████████████████| 71kB 8.5MB/s
# ...
#      |████████████████████████████████| 122kB 33.6MB/s
# ...
#      |████████████████████████████████| 6.8MB 30.3MB/s
# ...
#      |████████████████████████████████| 1.6MB 45.5MB/s
# ...
#      |████████████████████████████████| 3.6MB 30.4MB/s
# ...
#      |████████████████████████████████| 112kB 47.0MB/s
# ...
#      |████████████████████████████████| 748.8MB 22kB/s
# ...
#      |████████████████████████████████| 20.2MB 1.2MB/s
# ...
#      |████████████████████████████████| 645kB 47.7MB/s
# ...
#   Created wheel for pesq: filename=pesq-0.0.1-cp37-cp37m-linux_x86_64.whl size=160866 sha256=a01e8b5b4ab3039e76f4f6ef138d1f60ca016074acb4c1899a7a12023d590fba
#   Stored in directory: /root/.cache/pip/wheels/42/a8/44/839b6f59a7d142d84ff06bfabaaad2a3e60408ee153de9bf13
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!python /content/svoice/train.py

# %%
#!python /content/svoice/train.py epochs=2

# %%
#!python -m svoice.data.audio '/content/drive/MyDrive/DataSets/AudioSets/dataset_dn_random_seg_n_2/mix' > mix.json

# %%
#!python -m svoice.data.audio '/content/drive/MyDrive/DataSets/AudioSets/dataset_dn_random_seg_n_2/s1' > s1.json

# %%
#!python -m svoice.data.audio '/content/drive/MyDrive/DataSets/AudioSets/dataset_dn_random_seg_n_2/s2' > s2.json

# %% [markdown]
# # Evaluating

# %%
# !python -m svoice.evaluate
# Out:
# usage: Evaluate separation performance using MulCat blocks [-h]
#                                                            [--device DEVICE]
#                                                            [--sdr SDR]
#                                                            [--sample_rate SAMPLE_RATE]
#                                                            [--num_workers NUM_WORKERS]
#                                                            [-v]
#                                                            model_path data_dir
# Evaluate separation performance using MulCat blocks: error: the following arguments are required: model_path, data_dir

# %%
# !python -m svoice.evaluate /content/drive/MyDrive/ResultadosEntrenamiento/Audio_Separation/dn_svoice/outputs/exp_/checkpoint.th /content/svoice/egs/debug/tr

# %%
print("Fin de evaluación!!!")
# Out:
# Fin de evaluación!!!

# %% [markdown]
# # Separate

# %%
# !python -m svoice.separate /content/drive/MyDrive/ResultadosEntrenamiento/zTestModelos/svoice-separate/checkpoint.th /content/drive/MyDrive/ResultadosEntrenamiento/zTestModelos/svoice-separate/out --mix_dir=/content/drive/MyDrive/ResultadosEntrenamiento/zTestModelos/svoice-separate/mix
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/content/svoice/svoice/separate.py", line 133, in <module>
#     separate(args, local_out_dir=args.out_dir)
#   File "/content/svoice/svoice/separate.py", line 88, in separate
#     pkg = torch.load(args.model_path)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 584, in load
#     return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 842, in _load
#     result = unpickler.load()
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 834, in persistent_load
#     load_tensor(data_type, size, key, _maybe_decode_ascii(location))
# ...

# %%
print("Fin de separación!!!")
# Out:
# Fin de separación!!!
